# %%
import numpy as np
from tensorflow import keras
from keras.datasets import fashion_mnist

# %% [markdown]
# Завантаження датасету

# %%
(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
print("Розмір тренувального датасету:", len(train_data))
print("Мітки тренувального датасету:", train_labels)
print("Значення мітоки: від", min(train_labels), "до", max(train_labels))
print("Розмір тестового датасету:", len(test_data))
# Out:
# Розмір тренувального датасету: 60000
# Мітки тренувального датасету: [9 0 0 ... 3 0 5]
# Значення мітоки: від 0 до 9
# Розмір тестового датасету: 10000

# %%
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

num_samples = 5
plt.figure(figsize=(12, 4))

for i in range(num_samples):
    plt.subplot(1, num_samples, i + 1)
    plt.imshow(train_data[i], cmap='gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')

plt.show()

# %% [markdown]
# Початкові значення параметрів

# %%
num_classes = 10 # загальна кількість класів, у нашому випадку це цифри від 0 до 9
num_features = 784 # кількість атрибутів вхідного вектора 28 * 28 = 784

learning_rate = 0.001 # швидкість навчання нейронної мережі
training_steps = 50 # максимальне число епох
batch_size = 256 # перераховувати ваги мережі ми будемо не на всій вибірці, а на її випадковій підмножині з batch_size елементів

n_hidden_1 = 256 # кількість нейронів 1-го шару
n_hidden_2 = 128 # кількість нейронів 2-го шару

from keras.utils import to_categorical

# Перетворюємо цілочисельні пікселі на тип float32
x_train, x_test = np.array(train_data, np.float32), np.array(test_data, np.float32)

# Перетворюємо матриці розміром 28x28 пікселів у вектор з 784 елементів
x_train, x_test = x_train.reshape([-1, num_features]), x_test.reshape([-1, num_features])

# Нормалізуємо значення пікселів
x_train, x_test = x_train / 255., x_test / 255.

# Перетворюємо цілочисельні мітки на тип float32
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# Перетворюємо мітки в категорійний формат
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# %% [markdown]
# Створюємо модель
#
#
# Конфігурація :
#
# Кількість шарів - 3
#
# Функція активації внутрішніх шарів - ReLU
#
# Кількість нейронів 1 внутрішнього шару - 256
#
# Кількість нейронів 2 внутрішнього шару - 128
#
# Кількість епох - 50
#
# Розмір батчу - 256
#
# Оптимізатор - Adam
#
# Метод регуляризації - Dropout

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import losses
from keras import metrics

from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# Параметри для планувальника швидкості навчання
lr_schedule = ExponentialDecay(
    learning_rate,
    decay_steps=1000,
    decay_rate=0.9,
    staircase=True)

model = Sequential([
    Dense(n_hidden_1, activation='relu', input_shape=(num_features,)),
    Dropout(0.5),
    Dense(n_hidden_2, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax'),
])

# Використовуємо планувальник для оптимізатора
optimizer = Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235146 (918.54 KB)
# Trainable params: 235146 (918.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]
def model_fit(model):
    history = model.fit(
        partial_x_train,
        partial_y_train,
        epochs=training_steps,
        batch_size=batch_size,
        validation_data=(x_val, y_val)
    )
    return history

# %%
def history_visual(history):
    history_dict = history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']

    epochs = range(1, len(history_dict['accuracy']) + 1)

    plt.plot(epochs, loss_values, 'bo', label='Training loss')
    plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    plt.clf()
    val_acc_values = history_dict['val_accuracy']
    plt.plot(epochs, history_dict['accuracy'], 'bo', label='Training acc')
    plt.plot(epochs, history_dict['val_accuracy'], 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

# %%
history = model_fit(model)
history_visual(history)
# Out:
# Epoch 1/50
# 196/196 [==============================] - 7s 22ms/step - loss: 0.8707 - accuracy: 0.6915 - val_loss: 0.4933 - val_accuracy: 0.8257
# Epoch 2/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.5462 - accuracy: 0.8061 - val_loss: 0.4166 - val_accuracy: 0.8499
# Epoch 3/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.4928 - accuracy: 0.8264 - val_loss: 0.3998 - val_accuracy: 0.8531
# Epoch 4/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.4576 - accuracy: 0.8393 - val_loss: 0.3744 - val_accuracy: 0.8659
# Epoch 5/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.4369 - accuracy: 0.8438 - val_loss: 0.3618 - val_accuracy: 0.8713
# Epoch 6/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.4158 - accuracy: 0.8503 - val_loss: 0.3521 - val_accuracy: 0.8737
# Epoch 7/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.4042 - accuracy: 0.8555 - val_loss: 0.3469 - val_accuracy: 0.8745
# Epoch 8/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3909 - accuracy: 0.8587 - val_loss: 0.3466 - val_accuracy: 0.8693
# Epoch 9/50
# 196/196 [==============================] - 5s 23ms/step - loss: 0.3849 - accuracy: 0.8619 - val_loss: 0.3369 - val_accuracy: 0.8751
# Epoch 10/50
# 196/196 [==============================] - 6s 29ms/step - loss: 0.3771 - accuracy: 0.8651 - val_loss: 0.3365 - val_accuracy: 0.8775
# Epoch 11/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.3678 - accuracy: 0.8668 - val_loss: 0.3258 - val_accuracy: 0.8791
# Epoch 12/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3589 - accuracy: 0.8715 - val_loss: 0.3227 - val_accuracy: 0.8815
# Epoch 13/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.3539 - accuracy: 0.8724 - val_loss: 0.3257 - val_accuracy: 0.8836
# Epoch 14/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.3523 - accuracy: 0.8728 - val_loss: 0.3181 - val_accuracy: 0.8825
# Epoch 15/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.3458 - accuracy: 0.8752 - val_loss: 0.3218 - val_accuracy: 0.8790
# Epoch 16/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3379 - accuracy: 0.8763 - val_loss: 0.3124 - val_accuracy: 0.8832
# Epoch 17/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3335 - accuracy: 0.8784 - val_loss: 0.3087 - val_accuracy: 0.8842
# Epoch 18/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.3269 - accuracy: 0.8813 - val_loss: 0.3050 - val_accuracy: 0.8905
# Epoch 19/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3246 - accuracy: 0.8806 - val_loss: 0.3077 - val_accuracy: 0.8884
# Epoch 20/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.3217 - accuracy: 0.8840 - val_loss: 0.3050 - val_accuracy: 0.8896
# Epoch 21/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3154 - accuracy: 0.8839 - val_loss: 0.2968 - val_accuracy: 0.8916
# Epoch 22/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.3100 - accuracy: 0.8859 - val_loss: 0.3009 - val_accuracy: 0.8902
# Epoch 23/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.3045 - accuracy: 0.8889 - val_loss: 0.3057 - val_accuracy: 0.8885
# Epoch 24/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.3070 - accuracy: 0.8871 - val_loss: 0.3000 - val_accuracy: 0.8904
# Epoch 25/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3008 - accuracy: 0.8903 - val_loss: 0.2996 - val_accuracy: 0.8912
# Epoch 26/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2993 - accuracy: 0.8909 - val_loss: 0.2942 - val_accuracy: 0.8947
# Epoch 27/50
# 196/196 [==============================] - 4s 20ms/step - loss: 0.2912 - accuracy: 0.8918 - val_loss: 0.2922 - val_accuracy: 0.8918
# Epoch 28/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2893 - accuracy: 0.8939 - val_loss: 0.3005 - val_accuracy: 0.8920
# Epoch 29/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.2881 - accuracy: 0.8940 - val_loss: 0.2953 - val_accuracy: 0.8929
# Epoch 30/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2843 - accuracy: 0.8955 - val_loss: 0.2941 - val_accuracy: 0.8942
# Epoch 31/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.2843 - accuracy: 0.8963 - val_loss: 0.2931 - val_accuracy: 0.8945
# Epoch 32/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.2820 - accuracy: 0.8955 - val_loss: 0.2955 - val_accuracy: 0.8964
# Epoch 33/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.2770 - accuracy: 0.8972 - val_loss: 0.2931 - val_accuracy: 0.8933
# Epoch 34/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2739 - accuracy: 0.8989 - val_loss: 0.2867 - val_accuracy: 0.8970
# Epoch 35/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.2760 - accuracy: 0.8980 - val_loss: 0.2976 - val_accuracy: 0.8927
# Epoch 36/50
# 196/196 [==============================] - 5s 24ms/step - loss: 0.2716 - accuracy: 0.9003 - val_loss: 0.2921 - val_accuracy: 0.8946
# Epoch 37/50
# 196/196 [==============================] - 3s 15ms/step - loss: 0.2657 - accuracy: 0.9003 - val_loss: 0.2880 - val_accuracy: 0.8961
# Epoch 38/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2652 - accuracy: 0.9009 - val_loss: 0.2852 - val_accuracy: 0.8972
# Epoch 39/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2667 - accuracy: 0.9014 - val_loss: 0.2897 - val_accuracy: 0.8950
# Epoch 40/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.2596 - accuracy: 0.9041 - val_loss: 0.2886 - val_accuracy: 0.8970
# Epoch 41/50
# 196/196 [==============================] - 3s 16ms/step - loss: 0.2606 - accuracy: 0.9036 - val_loss: 0.2887 - val_accuracy: 0.8967
# Epoch 42/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.2589 - accuracy: 0.9040 - val_loss: 0.2895 - val_accuracy: 0.8962
# Epoch 43/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.2517 - accuracy: 0.9067 - val_loss: 0.2930 - val_accuracy: 0.8955
# Epoch 44/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2507 - accuracy: 0.9062 - val_loss: 0.2858 - val_accuracy: 0.8993
# Epoch 45/50
# 196/196 [==============================] - 4s 21ms/step - loss: 0.2483 - accuracy: 0.9077 - val_loss: 0.2894 - val_accuracy: 0.8962
# Epoch 46/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.2512 - accuracy: 0.9073 - val_loss: 0.2841 - val_accuracy: 0.8989
# Epoch 47/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2465 - accuracy: 0.9083 - val_loss: 0.2895 - val_accuracy: 0.8961
# Epoch 48/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2464 - accuracy: 0.9077 - val_loss: 0.2880 - val_accuracy: 0.8973
# Epoch 49/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.2431 - accuracy: 0.9088 - val_loss: 0.2862 - val_accuracy: 0.8977
# Epoch 50/50
# 196/196 [==============================] - 4s 19ms/step - loss: 0.2432 - accuracy: 0.9111 - val_loss: 0.2845 - val_accuracy: 0.9000

# %% [markdown]
# Висновок:
#
# Побудована модель включає регуляризатор Dropout, який випадковим чином вимикає деякі нейрони під час навчання, тим самим підвищуючи стійкість мережі. Застосування планувальника швидкості навчання дозволило покращити продуктивність моделі. Використання функції активації ReLU та оптимізатора Adam забезпечило досягнення високих результатів: точність моделі на тестових даних становить приблизно 91%, а максимальна точність на валідаційних даних склала близько 90%.

# %% [markdown]
# Результати роботи моделі на тестових даних

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3165 - accuracy: 0.8914
# Test Loss: 0.3164675235748291
# Test Accuracy: 0.8913999795913696

# %% [markdown]
# Передбачення для тестових даних

# %%
predictions = model.predict(x_test)

print(f'Predictions for the first example: {predictions[0]}')

predicted_classes = np.argmax(predictions, axis=1)

print(f'Predicted classes for the first examples: {predicted_classes[:10]}')
print(f'Real classes for the first examples: {test_labels[:10]}')
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Predictions for the first example: [6.9016209e-11 8.0940996e-09 6.6307252e-13 3.4826493e-13 1.3347509e-12
#  8.6282780e-05 7.6333245e-11 1.8730627e-04 4.5208845e-12 9.9972641e-01]
# Predicted classes for the first examples: [9 2 1 1 6 1 4 6 5 7]
# Real classes for the first examples: [9 2 1 1 6 1 4 6 5 7]

# %%
num_samples = 7
plt.figure(figsize=(12, 4))

for i in range(num_samples):
    plt.subplot(2, num_samples, i + 1)
    plt.imshow(test_data[i], cmap='gray')
    plt.title(f"Label: {test_labels[i]}")
    plt.axis('off')

    plt.subplot(2, num_samples, i + num_samples + 1)
    plt.bar(range(10), predictions[i], color='green', alpha=0.7)
    plt.title(f"Predicted: {predicted_classes[i]}")
    plt.xticks(range(10))
    plt.xlabel("Class")
    plt.ylabel("Probability")

plt.tight_layout()
plt.show()
